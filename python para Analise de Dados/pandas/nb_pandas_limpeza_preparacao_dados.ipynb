# %% [markdown]
# # Limpeza e preparação dos dados

# %% [markdown]
# ## Dados Ausentes
#
# Dados ausentes podem ser representados por NAN (Not a Number) ou NONE, esse tipo de dados no PANDAS são considerados NA ( Not Available)

# %% [markdown]
# ### Excluindo Dados Ausentes

# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame([
    [1,6.5,3],
    [1, np.nan, None],
    [np.nan,np.nan,np.nan],
    [np.nan,6.5,3],
    [None, None, None]
])

display(data)

# remove os Valores Ausentes
display(data.dropna().style.set_caption('Remove os Valores Ausentes'))

# Remove apenas as linhas com todos os Valores Ausentes
display(data.dropna(how="all").style.set_caption('Remove apenas as linhas com todos os Valores Ausentes'))

data['new_column'] = np.nan
display(data)

# Remove apenas as colunas com todos os Valores Ausentes
display(data.dropna(how="all", axis='columns').style.set_caption('Remove apenas as colunas com todos os Valores Ausentes'))
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0
# 4  NaN  NaN  NaN
# <style type="text/css">
# </style>
# <table id="T_8f6ac">
#   <caption>Remove os Valores Ausentes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f6ac_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_8f6ac_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_8f6ac_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f6ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f6ac_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8f6ac_row0_col1" class="data row0 col1" >6.500000</td>
#       <td id="T_8f6ac_row0_col2" class="data row0 col2" >3.000000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_93041">
#   <caption>Remove apenas as linhas com todos os Valores Ausentes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93041_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_93041_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_93041_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93041_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_93041_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_93041_row0_col1" class="data row0 col1" >6.500000</td>
#       <td id="T_93041_row0_col2" class="data row0 col2" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93041_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_93041_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_93041_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_93041_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_93041_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_93041_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_93041_row2_col1" class="data row2 col1" >6.500000</td>
#       <td id="T_93041_row2_col2" class="data row2 col2" >3.000000</td>
#     </tr>
#   </tbody>
# </table>
#      0    1    2  new_column
# 0  1.0  6.5  3.0         NaN
# 1  1.0  NaN  NaN         NaN
# 2  NaN  NaN  NaN         NaN
# 3  NaN  6.5  3.0         NaN
# 4  NaN  NaN  NaN         NaN
# <style type="text/css">
# </style>
# <table id="T_cc177">
#   <caption>Remove apenas as colunas com todos os Valores Ausentes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc177_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cc177_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_cc177_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc177_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc177_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_cc177_row0_col1" class="data row0 col1" >6.500000</td>
#       <td id="T_cc177_row0_col2" class="data row0 col2" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cc177_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cc177_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_cc177_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_cc177_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc177_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cc177_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_cc177_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_cc177_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc177_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cc177_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_cc177_row3_col1" class="data row3 col1" >6.500000</td>
#       <td id="T_cc177_row3_col2" class="data row3 col2" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cc177_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cc177_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_cc177_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_cc177_row4_col2" class="data row4 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Preenchendo Dados Ausentes

# %%
data2 = pd.DataFrame(np.random.standard_normal((7,3)))

data2.iloc[:4,0] = np.nan
data2.iloc[2:5,2] = np.nan

display(data2)

# Preenche os dados ausentes com um VALOR
display(data2.fillna('NULO').style.set_caption("Preenche os dados ausentes com um VALOR"))

# Preenche os dados ausentes com um VALOR diferente para cada coluna
display(data2.fillna({0:'NULO',2:'VAZIO'}).style.set_caption("Preenche os dados ausentes com um VALOR diferente para cada coluna"))
# Out:
#           0         1         2
# 0       NaN -2.105386  0.466196
# 1       NaN -0.842781  0.045549
# 2       NaN  0.937307       NaN
# 3       NaN -1.245970       NaN
# 4  0.096486 -0.529587       NaN
# 5 -1.135631  1.274999 -0.091634
# 6 -0.551180 -0.809739  0.511790
# <style type="text/css">
# </style>
# <table id="T_d00ca">
#   <caption>Preenche os dados ausentes com um VALOR</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d00ca_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d00ca_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d00ca_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d00ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d00ca_row0_col0" class="data row0 col0" >NULO</td>
#       <td id="T_d00ca_row0_col1" class="data row0 col1" >-2.105386</td>
#       <td id="T_d00ca_row0_col2" class="data row0 col2" >0.466196</td>
#     </tr>
#     <tr>
#       <th id="T_d00ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d00ca_row1_col0" class="data row1 col0" >NULO</td>
#       <td id="T_d00ca_row1_col1" class="data row1 col1" >-0.842781</td>
#       <td id="T_d00ca_row1_col2" class="data row1 col2" >0.045549</td>
#     </tr>
#     <tr>
#       <th id="T_d00ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d00ca_row2_col0" class="data row2 col0" >NULO</td>
#       <td id="T_d00ca_row2_col1" class="data row2 col1" >0.937307</td>
#       <td id="T_d00ca_row2_col2" class="data row2 col2" >NULO</td>
#     </tr>
#     <tr>
#       <th id="T_d00ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d00ca_row3_col0" class="data row3 col0" >NULO</td>
#       <td id="T_d00ca_row3_col1" class="data row3 col1" >-1.245970</td>
#       <td id="T_d00ca_row3_col2" class="data row3 col2" >NULO</td>
#     </tr>
#     <tr>
#       <th id="T_d00ca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d00ca_row4_col0" class="data row4 col0" >0.096486</td>
#       <td id="T_d00ca_row4_col1" class="data row4 col1" >-0.529587</td>
#       <td id="T_d00ca_row4_col2" class="data row4 col2" >NULO</td>
#     </tr>
#     <tr>
#       <th id="T_d00ca_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d00ca_row5_col0" class="data row5 col0" >-1.135631</td>
#       <td id="T_d00ca_row5_col1" class="data row5 col1" >1.274999</td>
#       <td id="T_d00ca_row5_col2" class="data row5 col2" >-0.091634</td>
#     </tr>
#     <tr>
#       <th id="T_d00ca_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d00ca_row6_col0" class="data row6 col0" >-0.551180</td>
#       <td id="T_d00ca_row6_col1" class="data row6 col1" >-0.809739</td>
#       <td id="T_d00ca_row6_col2" class="data row6 col2" >0.511790</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6218f">
#   <caption>Preenche os dados ausentes com um VALOR diferente para cada coluna</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6218f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6218f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6218f_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6218f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6218f_row0_col0" class="data row0 col0" >NULO</td>
#       <td id="T_6218f_row0_col1" class="data row0 col1" >-2.105386</td>
#       <td id="T_6218f_row0_col2" class="data row0 col2" >0.466196</td>
#     </tr>
#     <tr>
#       <th id="T_6218f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6218f_row1_col0" class="data row1 col0" >NULO</td>
#       <td id="T_6218f_row1_col1" class="data row1 col1" >-0.842781</td>
#       <td id="T_6218f_row1_col2" class="data row1 col2" >0.045549</td>
#     </tr>
#     <tr>
#       <th id="T_6218f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6218f_row2_col0" class="data row2 col0" >NULO</td>
#       <td id="T_6218f_row2_col1" class="data row2 col1" >0.937307</td>
#       <td id="T_6218f_row2_col2" class="data row2 col2" >VAZIO</td>
#     </tr>
#     <tr>
#       <th id="T_6218f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6218f_row3_col0" class="data row3 col0" >NULO</td>
#       <td id="T_6218f_row3_col1" class="data row3 col1" >-1.245970</td>
#       <td id="T_6218f_row3_col2" class="data row3 col2" >VAZIO</td>
#     </tr>
#     <tr>
#       <th id="T_6218f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6218f_row4_col0" class="data row4 col0" >0.096486</td>
#       <td id="T_6218f_row4_col1" class="data row4 col1" >-0.529587</td>
#       <td id="T_6218f_row4_col2" class="data row4 col2" >VAZIO</td>
#     </tr>
#     <tr>
#       <th id="T_6218f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6218f_row5_col0" class="data row5 col0" >-1.135631</td>
#       <td id="T_6218f_row5_col1" class="data row5 col1" >1.274999</td>
#       <td id="T_6218f_row5_col2" class="data row5 col2" >-0.091634</td>
#     </tr>
#     <tr>
#       <th id="T_6218f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6218f_row6_col0" class="data row6 col0" >-0.551180</td>
#       <td id="T_6218f_row6_col1" class="data row6 col1" >-0.809739</td>
#       <td id="T_6218f_row6_col2" class="data row6 col2" >0.511790</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Transformação de dados

# %% [markdown]
# ### Remoção de duplicidades

# %%
data = pd.DataFrame({"k1":["one","two"] * 3 + ["two"],
                     "k2":[1,1,2,3,3,4,4]
                     })

display(data)

# duplicated()
# retorna uma Serie boleana
print("resultado do metodo duplicated()")
display(data.duplicated())

# drop_duplicates()
# retorna uma Serie boleana
print("resultado do metodo drop_duplicates()")
display(data.drop_duplicates())
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4
# resultado do metodo duplicated()
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool
# resultado do metodo drop_duplicates()
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %% [markdown]
# #### Parametros de drop_duplicates

# %%
# Escolhendo a coluna para calcular duplicidades

# subset: define a coluna para observar a DUPLICIDADE
display(data.drop_duplicates(subset=["k1"]))

# keep: define o a orientação para aplicar a DUPLICIDADE
display(data.drop_duplicates(subset=["k1"], keep="last"))
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
#     k1  k2
# 4  one   3
# 6  two   4

# %% [markdown]
# ### Transformação com Função ou Mapeamento

# %%
data = pd.DataFrame({
    "food":["bacon", "pulled pork", "bacon", "pastrami", "corned beef", "bacon", "pastrami", "honey ham", "nova lox"],
    "ounces":[4, 3, 12, 6, 7.5, 8, 3, 5, 6]
})

display(data)
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     pastrami     6.0
# 4  corned beef     7.5
# 5        bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %% [markdown]
# Criaremos um MAPEAMENTO para adicionar o TIPO DE CARNE para o TIPO DE ANIMAL:

# %%
# Dicionario do mapeamento
meat_to_animal = {
    "bacon":"pig",
    "pulled pork": "pig",
    "pastrami":"cow",
    "corned beef":"cow",
    "honey ham":"pig",
    "nova lox":"salmon"
}

# data["food"] => Série da coluna que iremos nos basear para aplicar o mapeamento
# "animal" => é a nova coluna no dataframe
print("usando DICIONARIO para o mapeamento")
data["animal"] = data["food"].map(meat_to_animal)

display(data)

print("usando FUNÇÃO para o mapeamento")
data.drop(columns=['animal'],inplace=True)
def get_animal(x):
    return meat_to_animal[x]

data["animalFuncao"] = data["food"].map(get_animal)

display(data)

# Para TRANSFORMAÇÃO nos valores do dataframe também é possível usar o método REPLACE
# Out:
# usando DICIONARIO para o mapeamento
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon
# usando FUNÇÃO para o mapeamento
#           food  ounces animalFuncao
# 0        bacon     4.0          pig
# 1  pulled pork     3.0          pig
# 2        bacon    12.0          pig
# 3     pastrami     6.0          cow
# 4  corned beef     7.5          cow
# 5        bacon     8.0          pig
# 6     pastrami     3.0          cow
# 7    honey ham     5.0          pig
# 8     nova lox     6.0       salmon

# %% [markdown]
# ### Renomeação de índices dos eixos

# %% [markdown]
# Os indices TAMBÉM podem ser renomeados, e para isso podemos usar o MAP do objeto INDEX, ou um dicionário assim como é feito com os dados do dataframe

# %%
data = pd.DataFrame(np.arange(12).reshape((3, 4)),
                    index=["Ohio", "Colorado", "New York"],
                    columns=["one", "two", "three", "four"]
                    )

display(data)
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
# Limita o tamano do rótulo em 4 caracteres, todos maiusculos
def transform(x):
    return x[:4].upper()

data.index = data.index.map(transform)
display(data)
# Out:
#       one  two  three  four
# OHIO    0    1      2     3
# COLO    4    5      6     7
# NEW     8    9     10    11

# %%
# Rename
data.rename(index=str.title, columns=str.upper)
# Out:
#       ONE  TWO  THREE  FOUR
# Ohio    0    1      2     3
# Colo    4    5      6     7
# New     8    9     10    11

# %%
# Rename com dicionário
data.rename(index={"OHIO":"INDIANA"},
            columns={"three":"peekaboo"})
# Out:
#          one  two  peekaboo  four
# INDIANA    0    1         2     3
# COLO       4    5         6     7
# NEW        8    9        10    11
